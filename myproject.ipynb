# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np 
import pandas as pd

# %%
file=open("carsprices.csv", "r+")
df = pd.read_csv(file)
df.head()
# Out:
#         city car_maker     model  year condition  kilometers transmission  \
# 0  Al Riyadh    Toyota      Rush  2019      Used     14999.5    Automatic
# 1  Al Riyadh       Kia  Carnival  2006      Used         0.0    Automatic
# 2  Al Riyadh    Toyota     Camry  2014      Used     24999.5    Automatic
# 3  Al Riyadh      Ford    Fusion  2010      Used    200000.0    Automatic
# 4  Al Riyadh      Ford    Taurus  2018      Used      5000.0    Automatic
#
#        fuel  color            pay_method    price
# 0  Gasoline  White  Cash or Installments  58375.0
# 1  Gasoline   Grey             Cash Only  10000.0
# 2  Gasoline  White     Installments Only  58375.0
# 3  Gasoline  White             Cash Only  22425.4
# 4  Gasoline   Grey             Cash Only  22425.4

# %%
new_df = df.dropna()

# %%
df.dropna(inplace = True)

# %%
df.drop_duplicates(inplace = True)

# %%
print(df.info()) 
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          27 non-null     object
#  1   car_maker     27 non-null     object
#  2   model         27 non-null     object
#  3   year          27 non-null     int64
#  4   condition     27 non-null     object
#  5   kilometers    27 non-null     float64
#  6   transmission  27 non-null     object
#  7   fuel          27 non-null     object
#  8   color         27 non-null     object
#  9   pay_method    27 non-null     object
#  10  price         27 non-null     float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 2.5+ KB
# None
#         city car_maker     model  year condition  kilometers transmission  \
# 0  Al Riyadh    Toyota      Rush  2019      Used     14999.5    Automatic
# 1  Al Riyadh       Kia  Carnival  2006      Used         0.0    Automatic
# 2  Al Riyadh    Toyota     Camry  2014      Used     24999.5    Automatic
# 3  Al Riyadh      Ford    Fusion  2010      Used    200000.0    Automatic
# 4  Al Riyadh      Ford    Taurus  2018      Used      5000.0    Automatic
#
#        fuel  color            pay_method    price
# 0  Gasoline  White  Cash or Installments  58375.0
# 1  Gasoline   Grey             Cash Only  10000.0
# 2  Gasoline  White     Installments Only  58375.0
# 3  Gasoline  White             Cash Only  22425.4
# 4  Gasoline   Grey             Cash Only  22425.4

# %%
print(df[['city', 'car_maker', 'year', 'price']])
# Out:
#          city car_maker  year     price
# 0   Al Riyadh    Toyota  2019   58375.0
# 1   Al Riyadh       Kia  2006   10000.0
# 2   Al Riyadh    Toyota  2014   58375.0
# 3   Al Riyadh      Ford  2010   22425.4
# 4   Al Riyadh      Ford  2018   22425.4
# 5   Al Riyadh   Renault  2016   20000.0
# 6   Al Riyadh    Toyota  2019   98500.0
# 7   Al Riyadh      Ford  2014   45000.0
# 8   Al Riyadh    Nissan  2009   36000.0
# 9   Al Riyadh      Ford  2014    2114.0
# 10  Al Riyadh       BMW  2008   25000.0
# 11  Al Riyadh  Cadillac  2008   40000.0
# 12  Al Riyadh      Ford  2011   23000.0
# 13  Al Riyadh    Toyota  2008   58375.0
# 14  Al Riyadh    Toyota  2008   30000.0
# 15  Al Riyadh     Mazda  2013   16000.0
# 16  Al Riyadh      Ford  2013   42000.0
# 17  Al Riyadh       Kia  2008   10000.0
# 18  Al Riyadh       BMW  2007   62500.0
# 19  Al Riyadh       GMC  2007   22000.0
# 21  Al Riyadh   Renault  2016   12000.0
# 22  Al Riyadh    Toyota  2009   11000.0
# 23  Al Riyadh     Dodge  2012   35000.0
# 24  Al Riyadh       Kia  2015   10000.0
# 25  Al Riyadh       BMW  2014  100000.0
# 26  Al Riyadh    Suzuki  2013   24000.0
# 27  Al Riyadh    Toyota  2016   94000.0

# %%
dupl = vet_visits.drop_duplicates(subset=["car_maker", "year", "kilometers", "color", "price"])
print(dupl)
# Out:
#          city car_maker           model  year condition  kilometers  \
# 0   Al Riyadh    Toyota            Rush  2019      Used     14999.5
# 1   Al Riyadh       Kia        Carnival  2006      Used         0.0
# 2   Al Riyadh    Toyota           Camry  2014      Used     24999.5
# 3   Al Riyadh      Ford          Fusion  2010      Used    200000.0
# 4   Al Riyadh      Ford          Taurus  2018      Used      5000.0
# 5   Al Riyadh   Renault      Dokker Van  2016      Used     64999.5
# 6   Al Riyadh    Toyota           Camry  2019       New         0.0
# 7   Al Riyadh      Ford          Fusion  2014      Used    104999.5
# 8   Al Riyadh    Nissan          Patrol  2009      Used    200000.0
# 9   Al Riyadh      Ford      Expedition  2014      Used    200000.0
# 10  Al Riyadh       BMW              X5  2008      Used    200000.0
# 11  Al Riyadh  Cadillac        Escalade  2008      Used    174999.5
# 12  Al Riyadh      Ford  Crown Victoria  2011      Used    144999.5
# 13  Al Riyadh    Toyota           Prado  2008      Used    200000.0
# 14  Al Riyadh    Toyota          Avalon  2008      Used    200000.0
# 15  Al Riyadh     Mazda               3  2013      Used    154999.5
# 16  Al Riyadh      Ford        Explorer  2013      Used    194999.5
# 17  Al Riyadh       Kia          Opirus  2008      Used      5000.0
# 18  Al Riyadh       BMW             740  2007      Used    200000.0
# 19  Al Riyadh       GMC           Envoy  2007      Used    200000.0
# 21  Al Riyadh   Renault          Symbol  2016      Used     44999.5
# 22  Al Riyadh    Toyota           Yaris  2009      Used    200000.0
# 23  Al Riyadh     Dodge         Durango  2012      Used    200000.0
# 24  Al Riyadh       Kia             Rio  2015      Used     44999.5
# 25  Al Riyadh       BMW             730  2014      Used    114999.5
# 26  Al Riyadh    Suzuki           Other  2013      Used     14999.5
# 27  Al Riyadh    Toyota        Fortuner  2016      Used     64999.5
#
#    transmission      fuel   color            pay_method     price
# 0     Automatic  Gasoline   White  Cash or Installments   58375.0
# 1     Automatic  Gasoline    Grey             Cash Only   10000.0
# 2     Automatic  Gasoline   White     Installments Only   58375.0
# 3     Automatic  Gasoline   White             Cash Only   22425.4
# 4     Automatic  Gasoline    Grey             Cash Only   22425.4
# 5        Manual  Gasoline   White             Cash Only   20000.0
# 6     Automatic  Gasoline   White  Cash or Installments   98500.0
# 7     Automatic  Gasoline   Black             Cash Only   45000.0
# 8        Manual  Gasoline   White             Cash Only   36000.0
# 9     Automatic  Gasoline   Black     Installments Only    2114.0
# 10    Automatic  Gasoline  Silver             Cash Only   25000.0
# 11    Automatic  Gasoline   Black  Cash or Installments   40000.0
# 12    Automatic  Gasoline  Silver             Cash Only   23000.0
# 13    Automatic  Gasoline   White             Cash Only   58375.0
# 14    Automatic  Gasoline   White             Cash Only   30000.0
# 15    Automatic  Gasoline   Green             Cash Only   16000.0
# 16    Automatic  Gasoline  Silver             Cash Only   42000.0
# 17    Automatic  Gasoline    Grey             Cash Only   10000.0
# 18    Automatic  Gasoline   Black             Cash Only   62500.0
# 19    Automatic  Gasoline   White             Cash Only   22000.0
# 21    Automatic  Gasoline  Silver             Cash Only   12000.0
# 22    Automatic  Gasoline   Green             Cash Only   11000.0
# 23    Automatic  Gasoline    Grey             Cash Only   35000.0
# 24    Automatic  Gasoline   Beige             Cash Only   10000.0
# 25    Automatic  Gasoline   Brown             Cash Only  100000.0
# 26       Manual  Gasoline   White             Cash Only   24000.0
# 27    Automatic  Gasoline   White             Cash Only   94000.0

# %%
manprice = df["price"]
man_price = manprice.max()
print(man_price)
# Out:
# 100000.0

# %%
manprice = df["price"]
man_price = manprice.min()
print(man_price)
# Out:
# 2114.0

# %%
df.sort_values(by=['year'])
# Out:
#          city car_maker           model  year condition  kilometers  \
# 1   Al Riyadh       Kia        Carnival  2006      Used         0.0
# 18  Al Riyadh       BMW             740  2007      Used    200000.0
# 19  Al Riyadh       GMC           Envoy  2007      Used    200000.0
# 13  Al Riyadh    Toyota           Prado  2008      Used    200000.0
# 17  Al Riyadh       Kia          Opirus  2008      Used      5000.0
# 14  Al Riyadh    Toyota          Avalon  2008      Used    200000.0
# 11  Al Riyadh  Cadillac        Escalade  2008      Used    174999.5
# 10  Al Riyadh       BMW              X5  2008      Used    200000.0
# 8   Al Riyadh    Nissan          Patrol  2009      Used    200000.0
# 22  Al Riyadh    Toyota           Yaris  2009      Used    200000.0
# 3   Al Riyadh      Ford          Fusion  2010      Used    200000.0
# 12  Al Riyadh      Ford  Crown Victoria  2011      Used    144999.5
# 23  Al Riyadh     Dodge         Durango  2012      Used    200000.0
# 26  Al Riyadh    Suzuki           Other  2013      Used     14999.5
# 15  Al Riyadh     Mazda               3  2013      Used    154999.5
# 16  Al Riyadh      Ford        Explorer  2013      Used    194999.5
# 9   Al Riyadh      Ford      Expedition  2014      Used    200000.0
# 25  Al Riyadh       BMW             730  2014      Used    114999.5
# 2   Al Riyadh    Toyota           Camry  2014      Used     24999.5
# 7   Al Riyadh      Ford          Fusion  2014      Used    104999.5
# 24  Al Riyadh       Kia             Rio  2015      Used     44999.5
# 27  Al Riyadh    Toyota        Fortuner  2016      Used     64999.5
# 5   Al Riyadh   Renault      Dokker Van  2016      Used     64999.5
# 21  Al Riyadh   Renault          Symbol  2016      Used     44999.5
# 4   Al Riyadh      Ford          Taurus  2018      Used      5000.0
# 6   Al Riyadh    Toyota           Camry  2019       New         0.0
# 0   Al Riyadh    Toyota            Rush  2019      Used     14999.5
#
#    transmission      fuel   color            pay_method     price
# 1     Automatic  Gasoline    Grey             Cash Only   10000.0
# 18    Automatic  Gasoline   Black             Cash Only   62500.0
# 19    Automatic  Gasoline   White             Cash Only   22000.0
# 13    Automatic  Gasoline   White             Cash Only   58375.0
# 17    Automatic  Gasoline    Grey             Cash Only   10000.0
# 14    Automatic  Gasoline   White             Cash Only   30000.0
# 11    Automatic  Gasoline   Black  Cash or Installments   40000.0
# 10    Automatic  Gasoline  Silver             Cash Only   25000.0
# 8        Manual  Gasoline   White             Cash Only   36000.0
# 22    Automatic  Gasoline   Green             Cash Only   11000.0
# 3     Automatic  Gasoline   White             Cash Only   22425.4
# 12    Automatic  Gasoline  Silver             Cash Only   23000.0
# 23    Automatic  Gasoline    Grey             Cash Only   35000.0
# 26       Manual  Gasoline   White             Cash Only   24000.0
# 15    Automatic  Gasoline   Green             Cash Only   16000.0
# 16    Automatic  Gasoline  Silver             Cash Only   42000.0
# 9     Automatic  Gasoline   Black     Installments Only    2114.0
# 25    Automatic  Gasoline   Brown             Cash Only  100000.0
# 2     Automatic  Gasoline   White     Installments Only   58375.0
# 7     Automatic  Gasoline   Black             Cash Only   45000.0
# 24    Automatic  Gasoline   Beige             Cash Only   10000.0
# 27    Automatic  Gasoline   White             Cash Only   94000.0
# 5        Manual  Gasoline   White             Cash Only   20000.0
# 21    Automatic  Gasoline  Silver             Cash Only   12000.0
# 4     Automatic  Gasoline    Grey             Cash Only   22425.4
# 6     Automatic  Gasoline   White  Cash or Installments   98500.0
# 0     Automatic  Gasoline   White  Cash or Installments   58375.0

# %%
df.sort_values(by=['price'])
# Out:
#          city car_maker           model  year condition  kilometers  \
# 9   Al Riyadh      Ford      Expedition  2014      Used    200000.0
# 1   Al Riyadh       Kia        Carnival  2006      Used         0.0
# 24  Al Riyadh       Kia             Rio  2015      Used     44999.5
# 17  Al Riyadh       Kia          Opirus  2008      Used      5000.0
# 22  Al Riyadh    Toyota           Yaris  2009      Used    200000.0
# 21  Al Riyadh   Renault          Symbol  2016      Used     44999.5
# 15  Al Riyadh     Mazda               3  2013      Used    154999.5
# 5   Al Riyadh   Renault      Dokker Van  2016      Used     64999.5
# 19  Al Riyadh       GMC           Envoy  2007      Used    200000.0
# 3   Al Riyadh      Ford          Fusion  2010      Used    200000.0
# 4   Al Riyadh      Ford          Taurus  2018      Used      5000.0
# 12  Al Riyadh      Ford  Crown Victoria  2011      Used    144999.5
# 26  Al Riyadh    Suzuki           Other  2013      Used     14999.5
# 10  Al Riyadh       BMW              X5  2008      Used    200000.0
# 14  Al Riyadh    Toyota          Avalon  2008      Used    200000.0
# 23  Al Riyadh     Dodge         Durango  2012      Used    200000.0
# 8   Al Riyadh    Nissan          Patrol  2009      Used    200000.0
# 11  Al Riyadh  Cadillac        Escalade  2008      Used    174999.5
# 16  Al Riyadh      Ford        Explorer  2013      Used    194999.5
# 7   Al Riyadh      Ford          Fusion  2014      Used    104999.5
# 0   Al Riyadh    Toyota            Rush  2019      Used     14999.5
# 13  Al Riyadh    Toyota           Prado  2008      Used    200000.0
# 2   Al Riyadh    Toyota           Camry  2014      Used     24999.5
# 18  Al Riyadh       BMW             740  2007      Used    200000.0
# 27  Al Riyadh    Toyota        Fortuner  2016      Used     64999.5
# 6   Al Riyadh    Toyota           Camry  2019       New         0.0
# 25  Al Riyadh       BMW             730  2014      Used    114999.5
#
#    transmission      fuel   color            pay_method     price
# 9     Automatic  Gasoline   Black     Installments Only    2114.0
# 1     Automatic  Gasoline    Grey             Cash Only   10000.0
# 24    Automatic  Gasoline   Beige             Cash Only   10000.0
# 17    Automatic  Gasoline    Grey             Cash Only   10000.0
# 22    Automatic  Gasoline   Green             Cash Only   11000.0
# 21    Automatic  Gasoline  Silver             Cash Only   12000.0
# 15    Automatic  Gasoline   Green             Cash Only   16000.0
# 5        Manual  Gasoline   White             Cash Only   20000.0
# 19    Automatic  Gasoline   White             Cash Only   22000.0
# 3     Automatic  Gasoline   White             Cash Only   22425.4
# 4     Automatic  Gasoline    Grey             Cash Only   22425.4
# 12    Automatic  Gasoline  Silver             Cash Only   23000.0
# 26       Manual  Gasoline   White             Cash Only   24000.0
# 10    Automatic  Gasoline  Silver             Cash Only   25000.0
# 14    Automatic  Gasoline   White             Cash Only   30000.0
# 23    Automatic  Gasoline    Grey             Cash Only   35000.0
# 8        Manual  Gasoline   White             Cash Only   36000.0
# 11    Automatic  Gasoline   Black  Cash or Installments   40000.0
# 16    Automatic  Gasoline  Silver             Cash Only   42000.0
# 7     Automatic  Gasoline   Black             Cash Only   45000.0
# 0     Automatic  Gasoline   White  Cash or Installments   58375.0
# 13    Automatic  Gasoline   White             Cash Only   58375.0
# 2     Automatic  Gasoline   White     Installments Only   58375.0
# 18    Automatic  Gasoline   Black             Cash Only   62500.0
# 27    Automatic  Gasoline   White             Cash Only   94000.0
# 6     Automatic  Gasoline   White  Cash or Installments   98500.0
# 25    Automatic  Gasoline   Brown             Cash Only  100000.0

# %%
plt.figure(figsize=[20,10])
plt.scatter(df['car_maker'], df['model'],df['year'], df['price'])
plt.title('price of cars in Riydhe : ')
plt.show()

# %%
plt.figure(figsize=[20,10])
plt.plot(df['model'],df['year'], df['price'])

plt.show()
